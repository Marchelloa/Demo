# %%
from dash import Dash, dcc, html, Input, Output
import plotly.express as px
import pandas as pd
from class_ticker_descriptor import DataTicker

df = DataTicker('FIVE', 100, 180, False).data_cr

# %%
fig1 = px.line(df, y=['CLOSE', 'MA100'])
# fig1 = px.line(df, y='MA100')
fig1.add_vline(x = df.index[-100])
fig1.show()

# %%
import plotly.express as px
fig = px.bar(x=["a", "b", "c"], y=[1, 3, 2])
fig.write_html('first_figure.html', auto_open=True)

# %%
df = px.data.gapminder().query("continent=='Oceania'")
fig = px.line(df, x="year", y="lifeExp", color='country')
fig.show()

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminder_unfiltered.csv')

# %%
df.country
# Out:
# <bound method Series.count of 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 3308       Zimbabwe
# 3309       Zimbabwe
# 3310       Zimbabwe
# 3311       Zimbabwe
# 3312       Zimbabwe
# Name: country, Length: 3313, dtype: object>

# %%
from dash import Dash, html, dcc, callback, Output, Input
import plotly.express as px
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminder_unfiltered.csv')

# %%
df[df.country == 'Canada']
# Out:
#     country continent  year  lifeExp       pop    gdpPercap
# 500  Canada  Americas  1950   68.280  14011422  10581.26552
# 501  Canada  Americas  1951   68.550  14330675  10932.46678
# 502  Canada  Americas  1952   68.750  14785584  11367.16112
# 503  Canada  Americas  1953   69.130  15183375  11586.61455
# 504  Canada  Americas  1954   69.990  15636245  11173.25950
# 505  Canada  Americas  1955   70.050  16050356  11901.50949
# 506  Canada  Americas  1956   70.040  16445087  12555.54947
# 507  Canada  Americas  1957   69.960  17010154  12489.95006
# 508  Canada  Americas  1958   70.620  17462004  12384.41018
# 509  Canada  Americas  1959   70.660  17872034  12590.80033
# 510  Canada  Americas  1960   71.040  18266765  12701.48312
# 511  Canada  Americas  1961   71.270  18634977  12817.92217
# 512  Canada  Americas  1962   71.300  18985849  13462.48555
# 513  Canada  Americas  1963   71.310  19342841  13882.56266
# 514  Canada  Americas  1964   71.690  19711053  14510.89933
# ...

# %%
sber = DataTicker('SBER', 100, 180, False)

# %%
df = sber.data_cr

# %%
df
# Out:
#      TICKER PER      DATE  TIME    OPEN    HIGH     LOW   CLOSE       MA100  \
# 0      SBER   D  19990601     0    5.86    5.86    5.65    5.65    5.755000
# 1      SBER   D  19990602     0    5.55    5.55    5.30    5.30    5.590000
# 2      SBER   D  19990603     0    5.40    5.66    5.40    5.65    5.569167
# 3      SBER   D  19990604     0    5.65    5.95    5.55    5.90    5.617500
# 4      SBER   D  19990607     0    5.87    5.90    5.85    5.85    5.667500
# ...     ...  ..       ...   ...     ...     ...     ...     ...         ...
# 5954   SBER   D  20230428     0  240.00  241.56  237.03  239.39  172.704125
# 5955   SBER   D  20230502     0  241.90  244.46  237.01  242.46  173.755950
# 5956   SBER   D  20230503     0  242.72  242.87  233.00  235.90  174.769100
# 5957   SBER   D  20230504     0  235.90  239.23  235.90  238.45  175.782475
# 5958   SBER   D  20230505     0  238.83  239.70  236.52  236.80  176.800175
#
# ...
